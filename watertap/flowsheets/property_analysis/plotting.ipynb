# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
# from matplotlib import cmsweep
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt

# %%
data_property_seawater = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_property_sea.csv')
data_property_nacl = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_property_nacl.csv')
data_property_simple = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_property_simple.csv')
data_property_reatoro = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_property_reaktoro.csv')

# %%
data_RO_seawater = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_RO_sea.csv')
data_RO_nacl = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_RO_nacl.csv')
data_RO_simple = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_RO_simple.csv')
data_RO_reatoro = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_RO_reaktoro.csv')

# %%
data_MVC_seawater = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_MVC_sea.csv')
data_MVC_nacl = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_MVC_nacl.csv')
data_MVC_simple = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\flowsheets\property_analysis\data_MVC_simple.csv')

data_MVC_seawater.dropna()
# Out:
#      # Water Recovery  Inlet Salinity      LCOW       SEC  Evaporator area  \
# 0             0.45000           0.035  4.343058  19.82570         642.7559
# 1             0.45000           0.070  4.417549  20.80071         670.4871
# 2             0.45375           0.035  4.337346  19.80166         649.1759
# 3             0.45375           0.070  4.413496  20.78930         677.1567
# 4             0.45750           0.035  4.331789  19.77842         655.5917
# ..                ...             ...       ...       ...              ...
# 157           0.74250           0.070  4.635558  24.31360        1146.3530
# 158           0.74625           0.035  4.222996  19.94728        1137.9490
# 159           0.74625           0.070  4.651527  24.49259        1150.5550
# 160           0.75000           0.035  4.226065  19.98633        1144.0070
# 161           0.75000           0.070  4.668350  24.68090        1154.5940
#
#      Compressor pressure ratio
# 0                     1.525539
# ...

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(3.5*3, 2.5*3)) #figsize=(3.5, 2.5)

axs[0,0].plot(data_RO_seawater['# Water Recovery']*100, data_RO_seawater['LCOW'])
axs[0,0].plot(data_RO_nacl['# Water Recovery']*100, data_RO_nacl['LCOW'])
axs[0,0].plot(data_RO_simple['# Water Recovery']*100, data_RO_simple['LCOW'])
axs[0,0].plot(data_RO_reatoro['# Water Recovery']*100, data_RO_reatoro['LCOW'])
# axs[0,0].legend(["Seawater","NaCl","Ideal"],title="Property model")
axs[0,0].set_xlabel("Water Recovery, %")
axs[0,0].set_ylabel("LCOW, $/m3")

axs[0,1].plot(data_RO_seawater['# Water Recovery']*100, data_RO_seawater['SEC'])
axs[0,1].plot(data_RO_nacl['# Water Recovery']*100, data_RO_nacl['SEC'])
axs[0,1].plot(data_RO_simple['# Water Recovery']*100, data_RO_simple['SEC'])
axs[0,1].plot(data_RO_reatoro['# Water Recovery']*100, data_RO_reatoro['SEC'])
# axs[0,1].legend(["Seawater","NaCl","Ideal"],title="Property model")
axs[0,1].set_xlabel("Water Recovery, %")
axs[0,1].set_ylabel("SEC, kJ/m3")

axs[1,0].plot(data_RO_seawater['# Water Recovery']*100, data_RO_seawater['Membrane Area'])
axs[1,0].plot(data_RO_nacl['# Water Recovery']*100, data_RO_nacl['Membrane Area'])
axs[1,0].plot(data_RO_simple['# Water Recovery']*100, data_RO_simple['Membrane Area'])
axs[1,0].plot(data_RO_reatoro['# Water Recovery']*100, data_RO_reatoro['Membrane Area'])
# axs[1,0].legend(["Seawater","NaCl","Ideal"],title="Property model")
axs[1,0].set_xlabel("Water Recovery, %")
axs[1,0].set_ylabel("Membrane Area, m2")

axs[1,1].plot(data_RO_seawater['# Water Recovery']*100, data_RO_seawater['Operating Pressure'])
axs[1,1].plot(data_RO_nacl['# Water Recovery']*100, data_RO_nacl['Operating Pressure'])
axs[1,1].plot(data_RO_simple['# Water Recovery']*100, data_RO_simple['Operating Pressure'])
axs[1,1].plot(data_RO_reatoro['# Water Recovery']*100, data_RO_reatoro['Operating Pressure'])

axs[1,1].set_xlabel("Water Recovery, %")
axs[1,1].set_ylabel("Operating Pressure, Pa")

axs[1,0].legend(["Seawater","NaCl","Ideal","Reaktoro"],title="Property model", loc="lower right")

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(3.5*3, 2.5*3))

data_MVC_seawater_low = data_MVC_seawater[(data_MVC_seawater["Inlet Salinity"] == 3.500000e-02) ]
data_MVC_nacl_low = data_MVC_nacl[(data_MVC_nacl["Inlet Salinity"] == 3.500000e-02) ]
data_MVC_simple_low = data_MVC_simple[(data_MVC_simple["Inlet Salinity"] == 3.500000e-02) ]

data_MVC_seawater_hi = data_MVC_seawater[(data_MVC_seawater["Inlet Salinity"] == 7.000000e-02) ]
data_MVC_nacl_hi = data_MVC_nacl[(data_MVC_nacl["Inlet Salinity"] == 7.000000e-02) ] 
data_MVC_simple_hi = data_MVC_simple[(data_MVC_simple["Inlet Salinity"] == 7.000000e-02) ] 

# axs[0,0].plot(data_MVC_seawater_low['# Water Recovery']*100, data_MVC_seawater_low['LCOW'])
axs[0,0].plot(data_MVC_seawater_hi['# Water Recovery']*100, data_MVC_seawater_hi['LCOW'])

# axs[0,0].plot(data_MVC_nacl_low['# Water Recovery']*100, data_MVC_nacl_low['LCOW'])
axs[0,0].plot(data_MVC_nacl_hi['# Water Recovery']*100, data_MVC_nacl_hi['LCOW'])

# axs[0,0].plot(data_MVC_simple_low['# Water Recovery']*100, data_MVC_simple_low['LCOW'])
axs[0,0].plot(data_MVC_simple_hi['# Water Recovery']*100, data_MVC_simple_hi['LCOW'])

axs[0,0].set_xlabel("Water Recovery, %")
axs[0,0].set_ylabel("LCOW, $/m3")

# axs[0,1].plot(data_MVC_seawater_low['# Water Recovery']*100, data_MVC_seawater_low['SEC'])
axs[0,1].plot(data_MVC_seawater_hi['# Water Recovery']*100, data_MVC_seawater_hi['SEC'])

# axs[0,1].plot(data_MVC_nacl_low['# Water Recovery']*100, data_MVC_nacl_low['SEC'])
axs[0,1].plot(data_MVC_nacl_hi['# Water Recovery']*100, data_MVC_nacl_hi['SEC'])

# axs[0,1].plot(data_MVC_simple_low['# Water Recovery']*100, data_MVC_simple_low['SEC'])
axs[0,1].plot(data_MVC_simple_hi['# Water Recovery']*100, data_MVC_simple_hi['SEC'])

axs[0,1].set_xlabel("Water Recovery, %")
axs[0,1].set_ylabel("SEC, kJ/m3")

# axs[1,0].plot(data_MVC_seawater_low['# Water Recovery']*100, data_MVC_seawater_low['Evaporator area'])
axs[1,0].plot(data_MVC_seawater_hi['# Water Recovery']*100, data_MVC_seawater_hi['Evaporator area'])

# axs[1,0].plot(data_MVC_nacl_low['# Water Recovery']*100, data_MVC_nacl_low['Evaporator area'])
axs[1,0].plot(data_MVC_nacl_hi['# Water Recovery']*100, data_MVC_nacl_hi['Evaporator area'])

# axs[1,0].plot(data_MVC_simple_low['# Water Recovery']*100, data_MVC_simple_low['Evaporator area'])
axs[1,0].plot(data_MVC_simple_hi['# Water Recovery']*100, data_MVC_simple_hi['Evaporator area'])

axs[1,0].set_xlabel("Water Recovery, %")
axs[1,0].set_ylabel("Evaporator Area, m2")

# axs[1,1].plot(data_MVC_seawater_low['# Water Recovery']*100, data_MVC_seawater_low['Compressor pressure ratio'])
axs[1,1].plot(data_MVC_seawater_hi['# Water Recovery']*100, data_MVC_seawater_hi['Compressor pressure ratio'])

# axs[1,1].plot(data_MVC_nacl_low['# Water Recovery']*100, data_MVC_nacl_low['Compressor pressure ratio'])
axs[1,1].plot(data_MVC_nacl_hi['# Water Recovery']*100, data_MVC_nacl_hi['Compressor pressure ratio'])

# axs[1,1].plot(data_MVC_simple_low['# Water Recovery']*100, data_MVC_simple_low['Compressor pressure ratio'])
axs[1,1].plot(data_MVC_simple_hi['# Water Recovery']*100, data_MVC_simple_hi['Compressor pressure ratio'])

axs[1,1].set_xlabel("Water Recovery, %")
axs[1,1].set_ylabel("Compressor pressure ratio")

axs[1,0].legend(["Seawater","NaCl","Ideal"],title="Property model", loc="lower right")
