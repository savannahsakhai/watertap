# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt
#import plotly.express as px
# %matplotlib ipympl

# %%
from analysis_plot_kit.core import fig_generator, data_import

# %%
# Reverse Osmosis

RO_NaCl = pd.read_csv('sal_outputs_results_RO_NaCl.csv')
RO_NaCl = RO_NaCl.dropna()
RO_NaCl = RO_NaCl.reset_index(drop=True)

RO_Sea = pd.read_csv('sal_outputs_results_RO_seawater.csv')
RO_Sea = RO_Sea.dropna()
RO_Sea = RO_Sea.reset_index(drop=True)

RO_Simple = pd.read_csv('sal_outputs_results_RO_simple.csv')
RO_Simple = RO_Simple.dropna()
RO_Simple = RO_Simple.reset_index(drop=True)

# %%
fig = plt.figure('Membrane Area')
ax = fig.add_subplot(projection='3d')
ax.scatter(RO_NaCl['# Water Recovery'], RO_NaCl['Inlet Salinity'], RO_NaCl['Membrane Area'])
ax.scatter(RO_Sea['# Water Recovery'], RO_Sea['Inlet Salinity'], RO_Sea['Membrane Area'])
ax.scatter(RO_Simple['# Water Recovery'], RO_Simple['Inlet Salinity'], RO_Simple['Membrane Area'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('Membrane Area')
# Out:
# Text(0.5, 0.92, 'Membrane Area')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('Operating Pressure')
ax = fig.add_subplot(projection='3d')
ax.scatter(RO_NaCl['# Water Recovery'],RO_NaCl['Inlet Salinity'], RO_NaCl['Operating Pressure'])
ax.scatter(RO_Sea['# Water Recovery'], RO_Sea['Inlet Salinity'], RO_Sea['Operating Pressure'])
ax.scatter(RO_Simple['# Water Recovery'], RO_Simple['Inlet Salinity'], RO_Simple['Operating Pressure'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('Operating Pressure')
# Out:
# Text(0.5, 0.92, 'Operating Pressure')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('LCOW')
ax = fig.add_subplot(projection='3d')
ax.scatter(RO_NaCl['# Water Recovery'], RO_NaCl['Inlet Salinity'], RO_NaCl['LCOW'])
ax.scatter(RO_Sea['# Water Recovery'], RO_Sea['Inlet Salinity'],RO_Sea['LCOW'])
ax.scatter(RO_Simple['# Water Recovery'], RO_Simple['Inlet Salinity'], RO_Simple['LCOW'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('LCOW')
# Out:
# Text(0.5, 0.92, 'LCOW')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('SEC')
ax = fig.add_subplot(projection='3d')
ax.scatter(RO_NaCl['# Water Recovery'], RO_NaCl['Inlet Salinity'], RO_NaCl['SEC'])
ax.scatter(RO_Sea['# Water Recovery'], RO_Sea['Inlet Salinity'], RO_Sea['SEC'])
ax.scatter(RO_Simple['# Water Recovery'], RO_Simple['Inlet Salinity'], RO_Simple['SEC'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('SEC')
# Out:
# Text(0.5, 0.92, 'SEC')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# MVC

MVC_NaCl = pd.read_csv('sal_outputs_results_MVC_NaCl.csv')
MVC_NaCl = MVC_NaCl.dropna()
MVC_NaCl = MVC_NaCl.reset_index(drop=True)
# MVC_NaCl= MVC_NaCl.drop(MVC_NaCl[(MVC_NaCl['# Water Recovery'] > .75)&(MVC_NaCl['Inlet Salinity'] > .05)].index)
# MVC_NaCl= MVC_NaCl.drop(MVC_NaCl[(MVC_NaCl['# Water Recovery'] > .65)&(MVC_NaCl['Inlet Salinity'] > .12)].index)



MVC_Sea = pd.read_csv('sal_outputs_results_MVC_seawater.csv')
MVC_Sea = MVC_Sea.dropna()
MVC_Sea = MVC_Sea.reset_index(drop=True)
# MVC_Sea= MVC_Sea.drop(MVC_Sea[(MVC_Sea['# Water Recovery'] > .75)&(MVC_Sea['Inlet Salinity'] > .05)].index)
# MVC_Sea= MVC_Sea.drop(MVC_Sea[(MVC_Sea['# Water Recovery'] > .65)&(MVC_Sea['Inlet Salinity'] > .12)].index)

MVC_Simple = pd.read_csv('sal_outputs_results_MVC_simple.csv')
MVC_Simple = MVC_Simple.dropna()
MVC_Simple = MVC_Simple.reset_index(drop=True)
# MVC_Simple = MVC_Simple.drop(MVC_Simple[(MVC_Simple['# Water Recovery'] > .75)&(MVC_Simple['Inlet Salinity'] > .05)].index)
# MVC_Simple = MVC_Simple.drop(MVC_Simple[(MVC_Simple['# Water Recovery'] > .65)&(MVC_Simple['Inlet Salinity'] > .12)].index)

# %%
fig = plt.figure('Evaporator area')
ax = fig.add_subplot(projection='3d')
ax.scatter(MVC_NaCl['# Water Recovery'], MVC_NaCl['Inlet Salinity'], MVC_NaCl['Evaporator area'])
ax.scatter(MVC_Sea['# Water Recovery'], MVC_Sea['Inlet Salinity'], MVC_Sea['Evaporator area'])
ax.scatter(MVC_Simple['# Water Recovery'], MVC_Simple['Inlet Salinity'], MVC_Simple['Evaporator area'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('Evaporator area')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('Evaporator temperature')
ax = fig.add_subplot(projection='3d')
ax.scatter(MVC_NaCl['# Water Recovery'], MVC_NaCl['Inlet Salinity'], MVC_NaCl['Evaporator temperature'])
ax.scatter(MVC_Sea['# Water Recovery'], MVC_Sea['Inlet Salinity'], MVC_Sea['Evaporator temperature'])
ax.scatter(MVC_Simple['# Water Recovery'], MVC_Simple['Inlet Salinity'], MVC_Simple['Evaporator temperature'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('Evaporator temperature')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('Evaporator pressure')
ax = fig.add_subplot(projection='3d')
ax.scatter(MVC_NaCl['# Water Recovery'], MVC_NaCl['Inlet Salinity'], MVC_NaCl['Evaporator pressure'])
ax.scatter(MVC_Sea['# Water Recovery'], MVC_Sea['Inlet Salinity'], MVC_Sea['Evaporator pressure'])
ax.scatter(MVC_Simple['# Water Recovery'], MVC_Simple['Inlet Salinity'], MVC_Simple['Evaporator pressure'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('Evaporator pressure')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('Compressor pressure ratio')
ax = fig.add_subplot(projection='3d')
ax.scatter(MVC_NaCl['# Water Recovery'], MVC_NaCl['Inlet Salinity'], MVC_NaCl['Compressor pressure ratio'])
ax.scatter(MVC_Sea['# Water Recovery'], MVC_Sea['Inlet Salinity'], MVC_Sea['Compressor pressure ratio'])
ax.scatter(MVC_Simple['# Water Recovery'], MVC_Simple['Inlet Salinity'], MVC_Simple['Compressor pressure ratio'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.title('Compressor pressure ratio')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('Specific energy consumption')
ax = fig.add_subplot(projection='3d')
ax.scatter(MVC_NaCl['# Water Recovery'], MVC_NaCl['Inlet Salinity'], MVC_NaCl['SEC'])
ax.scatter(MVC_Sea['# Water Recovery'], MVC_Sea['Inlet Salinity'], MVC_Sea['SEC'])
ax.scatter(MVC_Simple['# Water Recovery'], MVC_Simple['Inlet Salinity'], MVC_Simple['SEC'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure('LCOW')
ax = fig.add_subplot(projection='3d')
ax.scatter(MVC_NaCl['# Water Recovery'], MVC_NaCl['Inlet Salinity'], MVC_NaCl['LCOW'])
ax.scatter(MVC_Sea['# Water Recovery'], MVC_Sea['Inlet Salinity'], MVC_Sea['LCOW'])
ax.scatter(MVC_Simple['# Water Recovery'], MVC_Simple['Inlet Salinity'], MVC_Simple['LCOW'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Inlet Salinity')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
