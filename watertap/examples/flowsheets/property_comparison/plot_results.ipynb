# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt
#import plotly.express as px

# %%
# Reverse Osmosis

RO_NaCl = pd.read_csv('outputs_results_RO_NaCl.csv')
RO_NaCl = RO_NaCl.dropna()
RO_NaCl = RO_NaCl.reset_index(drop=True)

RO_Sea = pd.read_csv('outputs_results_RO_seawater.csv')
RO_Sea = RO_Sea.dropna()
RO_Sea = RO_Sea.reset_index(drop=True)

RO_Simple = pd.read_csv('outputs_results_RO_simple.csv')
RO_Simple = RO_Simple.dropna()
RO_Simple = RO_Simple.reset_index(drop=True)

# %%
fig1 = plt.figure('Membrane Area')
#ax = fig.add_subplot(projection='2d')
plt.plot(RO_NaCl['# Water Recovery'], RO_NaCl['Membrane Area'])
plt.plot(RO_Sea['# Water Recovery'], RO_Sea['Membrane Area'])
plt.plot(RO_Simple['# Water Recovery'], RO_Simple['Membrane Area'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Membrane Area')
# Out:
# Text(0, 0.5, 'Membrane Area')

# %%
fig2 = plt.figure('Operating Pressure')
#ax = fig.add_subplot(projection='2d')
plt.plot(RO_NaCl['# Water Recovery'], RO_NaCl['Operating Pressure'])
plt.plot(RO_Sea['# Water Recovery'], RO_Sea['Operating Pressure'])
plt.plot(RO_Simple['# Water Recovery'], RO_Simple['Operating Pressure'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Pressure')
# Out:
# Text(0, 0.5, 'Pressure')

# %%
# %matplotlib ipympl
# fig = plt.figure('Pump 1 pressure')
# ax = fig.add_subplot(projection='3d')

# ax.scatter(RO_NaCl['# Water Recovery'], RO_NaCl['Operating Pressure'], RO_NaCl['LCOW'])
# ax.scatter(RO_Sea['# Water Recovery'], RO_Sea['Operating Pressure'], RO_Sea['LCOW'])
# ax.scatter(RO_Simple['# Water Recovery'], RO_Simple['Operating Pressure'], RO_Simple['LCOW'])
# #ax.legend(['NaCl', 'Sea','Simple'])

# %%
fig = plt.figure('LCOW')
#ax = fig.add_subplot(projection='2d')
plt.plot(RO_NaCl['# Water Recovery'], RO_NaCl['LCOW'])
plt.plot(RO_Sea['# Water Recovery'], RO_Sea['LCOW'])
plt.plot(RO_Simple['# Water Recovery'], RO_Simple['LCOW'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('LCOW')
# Out:
# Text(0, 0.5, 'LCOW')

# %%
fig = plt.figure('SEC')
#ax = fig.add_subplot(projection='2d')
plt.plot(RO_NaCl['# Water Recovery'], RO_NaCl['SEC'])
plt.plot(RO_Sea['# Water Recovery'], RO_Sea['SEC'])
plt.plot(RO_Simple['# Water Recovery'], RO_Simple['SEC'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('SEC')
# Out:
# Text(0, 0.5, 'SEC')

# %%
# MVC

MVC_NaCl = pd.read_csv('outputs_results_MVC_NaCl.csv')
MVC_NaCl = MVC_NaCl.dropna()
MVC_NaCl = MVC_NaCl.reset_index(drop=True)

MVC_Sea = pd.read_csv('outputs_results_MVC_seawater.csv')
MVC_Sea = MVC_Sea.dropna()
MVC_Sea = MVC_Sea.reset_index(drop=True)

MVC_Simple = pd.read_csv('outputs_results_MVC_simple.csv')
MVC_Simple = MVC_Simple.dropna()
MVC_Simple = MVC_Simple.reset_index(drop=True)

# %%
fig = plt.figure('Evaporator area')
#ax = fig.add_subplot(projection='2d')
plt.plot(MVC_NaCl['# Water Recovery'], MVC_NaCl['Evaporator area'])
plt.plot(MVC_Sea['# Water Recovery'], MVC_Sea['Evaporator area'])
plt.plot(MVC_Simple['# Water Recovery'], MVC_Simple['Evaporator area'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Evaporator area')
# Out:
# Text(0, 0.5, 'Evaporator area')

# %%
fig = plt.figure('Evaporator temperature')
#ax = fig.add_subplot(projection='2d')
plt.plot(MVC_NaCl['# Water Recovery'], MVC_NaCl['Evaporator temperature'])
plt.plot(MVC_Sea['# Water Recovery'], MVC_Sea['Evaporator temperature'])
plt.plot(MVC_Simple['# Water Recovery'], MVC_Simple['Evaporator temperature'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Evaporator temperature')
# Out:
# Text(0, 0.5, 'Evaporator temperature')

# %%
fig = plt.figure('Evaporator pressure')
#ax = fig.add_subplot(projection='2d')
plt.plot(MVC_NaCl['# Water Recovery'], MVC_NaCl['Evaporator pressure'])
plt.plot(MVC_Sea['# Water Recovery'], MVC_Sea['Evaporator pressure'])
plt.plot(MVC_Simple['# Water Recovery'], MVC_Simple['Evaporator pressure'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Evaporator pressure')
# Out:
# Text(0, 0.5, 'Evaporator pressure')

# %%
fig = plt.figure('Compressor pressure ratio')
#ax = fig.add_subplot(projection='2d')
plt.plot(MVC_NaCl['# Water Recovery'], MVC_NaCl['Compressor pressure ratio'])
plt.plot(MVC_Sea['# Water Recovery'], MVC_Sea['Compressor pressure ratio'])
plt.plot(MVC_Simple['# Water Recovery'], MVC_Simple['Compressor pressure ratio'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('Compressor pressure ratio')
# Out:
# Text(0, 0.5, 'Compressor pressure ratio')

# %%
fig = plt.figure('Specific energy consumption')
#ax = fig.add_subplot(projection='2d')
plt.plot(MVC_NaCl['# Water Recovery'], MVC_NaCl['SEC'])
plt.plot(MVC_Sea['# Water Recovery'], MVC_Sea['SEC'])
plt.plot(MVC_Simple['# Water Recovery'], MVC_Simple['SEC'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('SEC')
# Out:
# Text(0, 0.5, 'SEC')

# %%
fig = plt.figure('LCOW')
#ax = fig.add_subplot(projection='2d')
plt.plot(MVC_NaCl['# Water Recovery'], MVC_NaCl['LCOW'])
plt.plot(MVC_Sea['# Water Recovery'], MVC_Sea['LCOW'])
plt.plot(MVC_Simple['# Water Recovery'], MVC_Simple['LCOW'])
plt.legend(['NaCl','Sea','Simple'])
plt.xlabel('Water Recovery')
plt.ylabel('LCOW')
# Out:
# Text(0, 0.5, 'LCOW')
