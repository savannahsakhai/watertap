# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt

# from analysis_plot_kit.core import fig_generator
# Out:
# C:\Users\sss0031\AppData\Local\Temp\1\ipykernel_13704\626070819.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('sensitivity_full_flowsheet1.csv')
data.dropna()
# Out:
#      # boron_feed  boron_limit      LCOW      SEC  RO1_Boron_rej  RO1_Feed_pH  \
# 0        0.001000       0.0003  0.915221  5.15273       0.565747          6.5
# 1        0.001000       0.0005  0.915221  5.15273       0.565747          6.5
# 2        0.001000       0.0010  0.915221  5.15273       0.565747          6.5
# 3        0.001000       0.0024  0.915221  5.15273       0.565747          6.5
# 4        0.001511       0.0003  0.918711  5.15273       0.565747          6.5
# ..            ...          ...       ...      ...            ...          ...
# 182      0.023979       0.0010  0.932324  5.15273       0.565747          6.5
# 183      0.023979       0.0024  0.927269  5.15273       0.565747          6.5
# 186      0.024489       0.0010  0.932444  5.15273       0.565747          6.5
# 187      0.024489       0.0024  0.927414  5.15273       0.565747          6.5
# 191      0.025000       0.0024  0.927554  5.15273       0.565747          6.5
#
# ...

# %%
fig = plt.figure()

data1 = data[(data["boron_limit"] == 3.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['RO2_Boron_rej'], 'o')
data1 = data[(data["boron_limit"] == 5.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['RO2_Boron_rej'], 'o')
data1 = data[(data["boron_limit"] == 1.0000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['RO2_Boron_rej'], 'o')
data1 = data[(data["boron_limit"] == 2.4000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['RO2_Boron_rej'], 'o')
plt.legend(["0.30 mg/L","0.50 mg/L","1.00 mg/L","2.40 mg/L"],title="Boron regulation", loc='lower right')

plt.xlabel("Inlet Boron Concentration, mg/L")
plt.ylabel("Boron Rejection in 2nd Pass")
# Out:
# Text(0, 0.5, 'Boron Rejection in 2nd Pass')

# %%
fig = plt.figure()

data1 = data[(data["boron_limit"] == 3.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['LCOW'], 'o')
data1 = data[(data["boron_limit"] == 5.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['LCOW'], 'o')
data1 = data[(data["boron_limit"] == 1.0000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['LCOW'], 'o')
data1 = data[(data["boron_limit"] == 2.4000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['LCOW'], 'o')
plt.legend(["0.30 mg/L","0.50 mg/L","1.00 mg/L","2.40 mg/L"],title="Boron regulation", loc='lower right')

plt.xlabel("Inlet Boron Concentration, mg/L")
plt.ylabel("LCOW, $/m3")
# Out:
# Text(0, 0.5, 'LCOW, $/m3')

# %%
fig = plt.figure()

data1 = data[(data["boron_limit"] == 3.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['SEC'], 'o')
data1 = data[(data["boron_limit"] == 5.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['SEC'], 'o')
data1 = data[(data["boron_limit"] == 1.0000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['SEC'], 'o')
data1 = data[(data["boron_limit"] == 2.4000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['SEC'], 'o')
plt.legend(["0.30 mg/L","0.50 mg/L","1.00 mg/L","2.40 mg/L"],title="Boron regulation", loc='lower right')

plt.xlabel("Inlet Boron Concentration, mg/L")
plt.ylabel("SEC, kWh/m3")
# Out:
# Text(0, 0.5, 'SEC, kWh/m3')

# %%
fig = plt.figure()

data1 = data[(data["boron_limit"] == 3.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['NaOH dose'], 'o')
data1 = data[(data["boron_limit"] == 5.00000e-04)]
plt.plot(data1['# boron_feed']*1000, data1['NaOH dose'], 'o')
data1 = data[(data["boron_limit"] == 1.0000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['NaOH dose'], 'o')
data1 = data[(data["boron_limit"] == 2.4000e-03)]
plt.plot(data1['# boron_feed']*1000, data1['NaOH dose'], 'o')
plt.legend(["0.30 mg/L","0.50 mg/L","1.00 mg/L","2.40 mg/L"],title="Boron regulation", loc='lower right')

plt.xlabel("Inlet Boron Concentration, mg/L")
plt.ylabel("NaOH dose, mg/kg w")
# Out:
# Text(0, 0.5, 'NaOH dose, mg/kg w')
