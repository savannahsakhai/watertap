# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
# from matplotlib import cmsweep
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt

from analysis_plot_kit.core import fig_generator

# %%
title_size = 14
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.fontset"] = "custom"
plt.rcParams['font.size'] = 14

light = "#85cced"
mid_light = "#5aa4cc"
mid_dark = "#317eac"
dark = "#07578c" 

color_list = [
                "#a6cee3",
                "#1f78b4",
                "#b2df8a",
                "#33a02c",
                "#fb9a99",
                "#e31a1c",
                "#fdbf6f",
                "#ff7f00",
                "#cab2d6",
                "#6a3d9a",
                "#ffff99",
                "#b15928",
            ]

# %%
light = color_list[0]
mid_light = color_list[2]
mid_dark = color_list[1]
dark = color_list[3]

# %%
data = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\watertap\examples\flowsheets\boron_removal\sensitivity_full_flowsheet_bwro1.csv')

# boron_feed,boron_limit,LCOW,SEC,Recovery,RO1_Boron_rej,RO1_Feed_pH,HCl dose,RO2_Boron_rej,RO2_Feed_pH,NaOH dose,Mem Area RO1,Mem Area RO2,P1,P2

# %%
data1 = data[(data["boron_limit"] == 3.000000e-04) ]
data2 = data[(data["boron_limit"] == 5.00000e-04) ]
data3 = data[(data["boron_limit"] == 1.0000e-03) ]
data4 = data[(data["boron_limit"] == 2.4000e-03) ]

fig = fig_generator.figureGenerator()
fig.init_figure(width=3.25*1.4,
                height=3.25*1.1,)
fig.plot_line(
        xdata=data4['# boron_feed']*1000, 
        ydata=data4['LCOW'] - 6.615159e-01,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data3['# boron_feed']*1000, 
        ydata=data3['LCOW'] - 6.615159e-01,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data2['# boron_feed']*1000, 
        ydata=data2['LCOW'] - 6.615159e-01,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data1['# boron_feed']*1000, 
        ydata=data1['LCOW'] - 6.615159e-01,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )

xformat=[[0, 25], 5]
yformat=[[0.225, 0.375], 0.025]
# # x-pltis
spacing_factor = 3
xlim = xformat[0]
xinc = xformat[1]
plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# y-pltis
ylim = yformat[0]
yinc = yformat[1]
plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

plt.xlabel("Feed concentration of boron (mg/L)")
plt.ylabel("LCOW difference ($\$$/m$^3$)")

plt.savefig("LCOW_diff_BWRO2", dpi=600)
# Out:
# WARNING: This tool kit is depreciated - please use psPlotKit - repo ( https://github.com/avdudchenko/psPlotKit )

# %%
data1 = data[(data["boron_limit"] == 3.000000e-04) ]
data2 = data[(data["boron_limit"] == 5.00000e-04) ]
data3 = data[(data["boron_limit"] == 1.0000e-03) ]
data4 = data[(data["boron_limit"] == 2.4000e-03) ]

fig = fig_generator.figureGenerator()
fig.init_figure(width=3.25*1.4,
                height=3.25*1.1,)
fig.plot_line(
        xdata=data4['# boron_feed']*1000, 
        ydata=100*((data4['LCOW'] - 6.615159e-01)/6.615159e-01),
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data3['# boron_feed']*1000, 
        ydata=100*((data3['LCOW'] - 6.615159e-01)/6.615159e-01),
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data2['# boron_feed']*1000, 
        ydata=100*((data2['LCOW'] - 6.615159e-01)/6.615159e-01),
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data1['# boron_feed']*1000, 
        ydata=100*((data1['LCOW'] - 6.615159e-01)/6.615159e-01),
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )

xformat=[[0, 25], 5]
yformat=[[35,55], 5]
# # x-pltis
spacing_factor = 3
xlim = xformat[0]
xinc = xformat[1]
plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# y-pltis
ylim = yformat[0]
yinc = yformat[1]
plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)
plt.xlabel("Feed concentration of boron (mg/L)")
plt.ylabel("Change in LCOW (%)")

plt.savefig("LCOW_%diff_BWRO2", dpi=600)
# Out:
# WARNING: This tool kit is depreciated - please use psPlotKit - repo ( https://github.com/avdudchenko/psPlotKit )

# %%
# plt.figure()

# data1 = data[(data["boron_limit"] == 3.000000e-04) ]
# data2 = data[(data["boron_limit"] == 5.00000e-04) ]
# data3 = data[(data["boron_limit"] == 1.0000e-03) ]
# data4 = data[(data["boron_limit"] == 2.4000e-03) ]


# plt.plot(data4['# boron_feed']*1000, data4['LCOW'] - 6.615159e-01, 'o', color=dark, markeredgecolor="black")
# plt.plot(data3['# boron_feed']*1000, data3['LCOW'] - 6.615159e-01, 'o', color=mid_dark, markeredgecolor="black")
# plt.plot(data2['# boron_feed']*1000, data2['LCOW'] - 6.615159e-01, 'o', color=mid_light,  markeredgecolor="black")
# plt.plot(data1['# boron_feed']*1000, data1['LCOW'] - 6.615159e-01, 'o', color=light, markeredgecolor="black")

# plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

# # plt.yticks(np.arange(0.225, 0.35, 0.025))

# xformat=[[0, 25], 5]
# yformat=[[0.225, 0.375], 0.025]
# # # x-pltis
# spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.xlabel("Feed concentration of boron (mg/L)")
# plt.ylabel("LCOW difference ($\$$/m$^3$)")

# plt.savefig("LCOW_diff_BWRO2", dpi=600)

# %%
# plt.figure()

# data1 = data[(data["boron_limit"] == 3.000000e-04) ]
# data2 = data[(data["boron_limit"] == 5.00000e-04) ]
# data3 = data[(data["boron_limit"] == 1.0000e-03) ]
# data4 = data[(data["boron_limit"] == 2.4000e-03) ]


# plt.plot(data4['# boron_feed']*1000, 100*((data4['LCOW'] - 6.615159e-01)/6.615159e-01), 'o', color=dark, markeredgecolor="black")
# plt.plot(data3['# boron_feed']*1000, 100*((data3['LCOW'] - 6.615159e-01)/6.615159e-01), 'o', color=mid_dark, markeredgecolor="black")
# plt.plot(data2['# boron_feed']*1000, 100*((data2['LCOW'] - 6.615159e-01)/6.615159e-01), 'o', color=mid_light, markeredgecolor="black")
# plt.plot(data1['# boron_feed']*1000, 100*((data1['LCOW'] - 6.615159e-01)/6.615159e-01), 'o', color=light, markeredgecolor="black")
# plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)


# plt.yticks(np.arange(35, 60, 5))

# xformat=[[0, 25], 5]
# yformat=[[35,55], 5]
# # # x-pltis
# spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.xlabel("Feed concentration of boron (mg/L)")
# plt.ylabel("Change in LCOW (%)")

# plt.savefig("LCOW_%diff_BWRO2", dpi=600)

# %%
data = pd.read_csv(r'G:\My Drive\Research\Dev\Boron Surrogate\sensitivity_full_flowsheet_membrane_properties_1.csv')

# %%
data1 = data[(data["boron_limit"] == 3.000000e-04) ]
data2 = data[(data["boron_limit"] == 5.00000e-04) ]
data3 = data[(data["boron_limit"] == 1.0000e-03) ]
data4 = data[(data["boron_limit"] == 2.4000e-03) ]

fig = fig_generator.figureGenerator()
fig.init_figure(width=3.25*1.4,
                height=3.25*1.1,)
fig.plot_line(
        xdata=data4['# boron_feed']*1000, 
        ydata=data4['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data3['# boron_feed']*1000, 
        ydata=data3['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data2['# boron_feed']*1000, 
        ydata=data2['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data1['# boron_feed']*1000, 
        ydata=data1['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )

plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

xformat=[[0, 25], 5]
yformat=[[50, 100], 10]
# # x-pltis
spacing_factor = 3
xlim = xformat[0]
xinc = xformat[1]
plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# y-pltis
ylim = yformat[0]
yinc = yformat[1]
plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

plt.xlabel("Feed concentration of boron (mg/L)")
plt.ylabel("Required boron rejection (%)")

plt.savefig("Rej_req_1stage", dpi=600)
# Out:
# WARNING: This tool kit is depreciated - please use psPlotKit - repo ( https://github.com/avdudchenko/psPlotKit )

# %%
# plt.figure()

# data1 = data[(data["boron_limit"] == 3.000000e-04) ]
# data2 = data[(data["boron_limit"] == 5.00000e-04) ]
# data3 = data[(data["boron_limit"] == 1.0000e-03) ]
# data4 = data[(data["boron_limit"] == 2.4000e-03) ]

# plt.plot(data4['# boron_feed']*1000, data4['RO1_Boron_rej']*100, 'o', color=dark, markeredgecolor="black")
# plt.plot(data3['# boron_feed']*1000, data3['RO1_Boron_rej']*100, 'o', color=mid_dark, markeredgecolor="black")
# plt.plot(data2['# boron_feed']*1000, data2['RO1_Boron_rej']*100, 'o', color=mid_light, markeredgecolor="black")
# plt.plot(data1['# boron_feed']*1000, data1['RO1_Boron_rej']*100, 'o',  color=light, markeredgecolor="black")

# plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

# xformat=[[0, 25], 5]
# yformat=[[50, 100], 10]
# # # x-pltis
# spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.xlabel("Feed concentration of boron (mg/L)")
# plt.ylabel("Required boron rejection (%)")

# plt.savefig("Rej_req_1stage", dpi=600)

# %%
s1 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_1.csv")
s2 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_2.csv")
s3 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_3.csv")
s4 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_4.csv")
s5 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_5.csv")
s6 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_6.csv")
s7 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_7.csv")
s8 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_8.csv")
s9 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_9.csv")
s10 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_10.csv")
s11 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_11.csv")
s12 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_12.csv")
s13 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_13.csv")
s14 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_14.csv")

# %%
# Original parameter names and grouping labels
parameters = ["HCl cost", "NaOH cost", "Electricity cost", "Water permeability", 
              "Water permeability", "Salt permeability", "Salt permeability",
              "Boron rejection in 1st pass RO", "Membrane cost", "Membrane replacement rate", 
              "Pump capital cost", "Mixer capital cost", "Boron rejection in 2nd pass RO $^{*}$","Feed pH of 1st pass RO"]

# Sample data for LCOW_low and LCOW_high (the reordered values should match your data)
LCOW_low = [s1["LCOW"][0], s2["LCOW"][0], s3["LCOW"][0], s4["LCOW"][0], s5["LCOW"][0], 
            s6["LCOW"][0], s7["LCOW"][0], s8["LCOW"][0], s9["LCOW"][0], s10["LCOW"][0], 
            s11["LCOW"][0], s12["LCOW"][0], s13["LCOW"][0], s14["LCOW"][0]]

LCOW_high = [s1["LCOW"][1], s2["LCOW"][1], s3["LCOW"][1], s4["LCOW"][1], s5["LCOW"][1], 
             s6["LCOW"][1], s7["LCOW"][1], s8["LCOW"][1], s9["LCOW"][1], s10["LCOW"][1], 
             s11["LCOW"][1], s12["LCOW"][1], s13["LCOW"][1], s14["LCOW"][1]]

# New ordered indices based on the new parameter order
indices_order = [13, 7, 12, 8, 9, 10, 11, 0, 1, 2]

# Reorder LCOW_low and LCOW_high based on the new indices
parameters = [parameters[i] for i in indices_order]
LCOW_low = [LCOW_low[i] for i in indices_order]
LCOW_high = [LCOW_high[i] for i in indices_order]


fig = fig_generator.figureGenerator()
fig.init_figure()

light = color_list[0]
mid_light = color_list[1]
dark = color_list[8]
econ =  color_list[2]
econ2 =  color_list[3]
color = [dark,
        mid_light,
        light,
    econ,econ,econ,econ,
    econ2,econ2,econ2,econ2,]

y_pos = np.arange(len(parameters))

width = []
bottom = []
for low, high in zip(LCOW_low, LCOW_high):
    width.append(abs(high - low))
    bottom.append(min(low, high))

# Loop over each parameter to plot individual bars with unique labels
for i, (y, w, b, label,c) in enumerate(zip(y_pos, width, bottom, parameters,color)):
    fig.plot_bar(
        [y],  # single y position
        [w],  # single width
        bottom=[b],  # single bottom position
        width=0.3,
        vertical=False,
        color=c,
        save_label=label,  # individual label for each bar
    )

# Additional plot settings
plt.yticks(y_pos, parameters)
plt.xlim(-13, 13)
plt.xlabel('Change in LCOW (%)')
plt.gca().invert_yaxis()

plt.savefig("boron_sensitivity", dpi=600, bbox_inches='tight')
# Out:
# WARNING: This tool kit is depreciated - please use psPlotKit - repo ( https://github.com/avdudchenko/psPlotKit )

# %%
# data = pd.read_csv(r'G:\My Drive\Research\Dev\Boron Surrogate\sensitivity_full_flowsheet_1.csv')

# boron_feed,boron_limit,LCOW,SEC,Recovery,RO1_Boron_rej,RO1_Feed_pH,HCl dose,RO2_Boron_rej,RO2_Feed_pH,NaOH dose,Mem Area RO1,Mem Area RO2,P1,P2

# %%
# plt.figure()

# data1 = data[(data["boron_limit"] == 3.000000e-04) ]
# data2 = data[(data["boron_limit"] == 5.00000e-04) ]
# data3 = data[(data["boron_limit"] == 1.0000e-03) ]
# data4 = data[(data["boron_limit"] == 2.4000e-03) ]

# plt.plot(data4['# boron_feed']*1000, data4['LCOW'] - 6.615159e-01, 'o',color=dark)
# plt.plot(data3['# boron_feed']*1000, data3['LCOW'] - 6.615159e-01, '^',color=mid_dark)
# plt.plot(data2['# boron_feed']*1000, data2['LCOW'] - 6.615159e-01, '*',color=mid_light)
# plt.plot(data1['# boron_feed']*1000, data1['LCOW'] - 6.615159e-01, 'd',color=light)

# plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

# xformat=[[0, 25], 5]
# yformat=[[0.225, 0.35], 0.025]
# # # x-pltis
# spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.xlabel("Inlet boron concentration (mg/L)")
# plt.ylabel("LCOW difference ($\$$/m$^3$)")

# plt.savefig("LCOW_diff_SWRO2", dpi=600)

# %%
# plt.figure()

# data1 = data[(data["boron_limit"] == 3.000000e-04) ]
# data2 = data[(data["boron_limit"] == 5.00000e-04) ]
# data3 = data[(data["boron_limit"] == 1.0000e-03) ]
# data4 = data[(data["boron_limit"] == 2.4000e-03) ]

# plt.plot(data4['# boron_feed']*1000, 100*((data1['LCOW'] - 6.615159e-01)/6.615159e-01), 'o',color=dark)
# plt.plot(data3['# boron_feed']*1000, 100*((data2['LCOW'] - 6.615159e-01)/6.615159e-01), '^',color=mid_dark)
# plt.plot(data2['# boron_feed']*1000, 100*((data3['LCOW'] - 6.615159e-01)/6.615159e-01), '*',color=mid_light)
# plt.plot(data1['# boron_feed']*1000, 100*((data4['LCOW'] - 6.615159e-01)/6.615159e-01), 'd',color=light)
# plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

# xformat=[[0, 25], 5]
# yformat=[[35,55], 5]
# # # x-pltis
# spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.xlabel("Inlet boron concentration (mg/L)")
# plt.ylabel("% differnece in LCOW")

# plt.savefig("LCOW_%diff_SWRO2", dpi=600)
