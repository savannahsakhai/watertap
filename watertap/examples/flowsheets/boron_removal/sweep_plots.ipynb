# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors as mcolors


# from analysis_plot_kit.core import fig_generator
from psPlotKit.data_plotter.fig_generator import figureGenerator
# Out:
# C:\Users\sss0031\AppData\Local\Temp\2\ipykernel_16248\1307494679.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
title_size = 14
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.fontset"] = "custom"
plt.rcParams['font.size'] = 14

light = "#85cced"
mid_light = "#5aa4cc"
mid_dark = "#317eac"
dark = "#07578c" 

color_list = [
                "#a6cee3",
                "#1f78b4",
                "#b2df8a",
                "#33a02c",
                "#fb9a99",
                "#e31a1c",
                "#fdbf6f",
                "#ff7f00",
                "#cab2d6",
                "#6a3d9a",
                "#ffff99",
                "#b15928",
            ]

# %%
light = color_list[0]
mid_light = color_list[2]
mid_dark = color_list[1]
dark = color_list[3]

# %%
data = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_full_flowsheet_bwro_map_1D1.csv')
data = data[data["# boron_feed"] < 25/1000]
# boron_feed,boron_limit,LCOW,SEC,Recovery,RO1_Boron_rej,RO1_Feed_pH,HCl dose,RO2_Boron_rej,RO2_Feed_pH,NaOH dose,Mem Area RO1,Mem Area RO2,P1,P2

# %%
figure = figureGenerator()
figure.init_figure()
figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
vmin = data['LCOW'].min()
vmax = data['LCOW'].max()
figure.plot_map(
    xdata=data['# boron_feed']*1000, 
    ydata=data["boron_limit"]*1000,
    zdata=data['LCOW'],
    text=True,
    textfontsize= 9,
    text_color="black",
    sig_figs_text=2,
    build_map=True,
    vmin=vmin,
    vmax=vmax,
    )
zticks = np.linspace(vmin,vmax,5)
figure.add_colorbar(zticks=zticks, 
                    zlabel="LCOW (\$/$m$^{3}$)", 
                    zformat=2, 
                    labelpad=15)
xticks = [1, 5, 10, 15, 20]
yticks = [0.3, 0.5, 1, 2.4]

figure.set_axis_ticklabels(
    xticklabels=xticks,
    yticklabels=yticks,
    xlabel="Feed concentration of boron (mg/L)",
    ylabel="Boron regulation (mg/L)",
)

plt.savefig("LCOW_BWRO2_map", dpi=600, bbox_inches='tight')
# Out:
# C:\Users\sss0031\AppData\Local\Temp\2\ipykernel_16248\2419816493.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
# (20,)
# [ 1.  5. 10. 15. 20.] [0.3 0.5 1.  2.4]
# [0] [0] 0.9899062 1.0 0.3
# [0] [1] 0.9888424 1.0 0.5
# [0] [2] 0.9888424 1.0 1.0
# [0] [3] 0.9888424 1.0 2.4
# [1] [0] 1.029972 5.0 0.3
# [1] [1] 1.012316 5.0 0.5
# [1] [2] 0.9988086 5.0 1.0
# [1] [3] 0.9888424 5.0 2.4
# [2] [0] 1.068336 10.0 0.3
# [2] [1] 1.0385 10.0 0.5
# [2] [2] 1.012316 10.0 1.0
# [2] [3] 0.9948154 10.0 2.4
# [3] [0] 1.09725 15.0 0.3
# [3] [1] 1.061513 15.0 0.5
# [3] [2] 1.025585 15.0 1.0
# [3] [3] 1.002751 15.0 2.4
# [4] [0] 1.120017 20.0 0.3
# [4] [1] 1.080835 20.0 0.5
# [4] [2] 1.0385 20.0 1.0
# [4] [3] 1.008054 20.0 2.4
# ...

# %%
figure = figureGenerator()
figure.init_figure()
figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
vmin = data['NaOH dose'].min()
vmax = data['NaOH dose'].max()
figure.plot_map(
    xdata=data['# boron_feed']*1000, 
    ydata=data["boron_limit"]*1000,
    zdata=data['NaOH dose'],
    text=True,
    textfontsize= 9,
    text_color="black",
    sig_figs_text=2,
    build_map=True,
    vmin=vmin,
    vmax=vmax,
    )
zticks = np.linspace(vmin,vmax,5)
figure.add_colorbar(zticks=zticks, zlabel="NaOH dose", zformat=2, labelpad=15)
xticks = [1, 5, 10, 15, 20]
yticks = [0.3, 0.5, 1, 2.4]

figure.set_axis_ticklabels(
    xticklabels=xticks,
    yticklabels=yticks,
    xlabel="Feed concentration of boron (mg/L)",
    ylabel="Boron regulation (mg/L)",
)

plt.savefig("LCOW_BWRO2_map", dpi=600, bbox_inches='tight')
# Out:
# C:\Users\sss0031\AppData\Local\Temp\2\ipykernel_16248\1934871410.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
# (20,)
# [ 1.  5. 10. 15. 20.] [0.3 0.5 1.  2.4]
# [0] [0] 3.418615 1.0 0.3
# [0] [1] 1.982085 1.0 0.5
# [0] [2] 1.982085 1.0 1.0
# [0] [3] 1.982085 1.0 2.4
# [1] [0] 59.87803 5.0 0.3
# [1] [1] 34.68587 5.0 0.5
# [1] [2] 15.59434 5.0 1.0
# [1] [3] 1.982085 5.0 2.4
# [2] [0] 114.6834 10.0 0.3
# [2] [1] 72.05885 10.0 0.5
# [2] [2] 34.68587 10.0 1.0
# [2] [3] 10.08481 10.0 2.4
# [3] [0] 156.0643 15.0 0.3
# [3] [1] 104.9305 15.0 0.5
# [3] [2] 53.61711 15.0 1.0
# [3] [3] 21.11162 15.0 2.4
# [4] [0] 188.6396 20.0 0.3
# [4] [1] 132.5761 20.0 0.5
# [4] [2] 72.05885 20.0 1.0
# [4] [3] 28.6132 20.0 2.4
# ...

# %%
figure = figureGenerator()
figure.init_figure()
figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
vmin = 100
vmax = 125
figure.plot_map(
    xdata=data['# boron_feed']*1000, 
    ydata=data["boron_limit"]*1000,
    zdata=100*((data['LCOW'] - 0.4956)/0.4956),
    text=True,
    textfontsize= 9,
    text_color="black",
    build_map=True,
    vmin=vmin,
    vmax=vmax,
    )
zticks = np.linspace(vmin,vmax,5)
figure.add_colorbar(zticks=zticks, zlabel="Change in LCOW (%)")
xticks = [1, 5, 10, 15, 20]
yticks = [0.3, 0.5, 1, 2.4]

figure.set_axis_ticklabels(
    xticklabels=xticks,
    yticklabels=yticks,
    xlabel="Feed concentration of boron (mg/L)",
    ylabel="Boron regulation (mg/L)",
)

plt.savefig("LCOW_diff_BWRO2_map", dpi=600, bbox_inches='tight')
# Out:
# C:\Users\sss0031\AppData\Local\Temp\2\ipykernel_16248\3652399121.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
# (20,)
# [ 1.  5. 10. 15. 20.] [0.3 0.5 1.  2.4]
# [0] [0] 99.73894269572236 1.0 0.3
# [0] [1] 99.52429378531075 1.0 0.5
# [0] [2] 99.52429378531075 1.0 1.0
# [0] [3] 99.52429378531075 1.0 2.4
# [1] [0] 107.82324455205814 5.0 0.3
# [1] [1] 104.26069410815172 5.0 0.5
# [1] [2] 101.53523002421308 5.0 1.0
# [1] [3] 99.52429378531075 5.0 2.4
# [2] [0] 115.56416464891039 10.0 0.3
# [2] [1] 109.54398708635995 10.0 0.5
# [2] [2] 104.26069410815172 10.0 1.0
# [2] [3] 100.72949959644876 10.0 2.4
# [3] [0] 121.39830508474576 15.0 0.3
# [3] [1] 114.18744955609361 15.0 0.5
# [3] [2] 106.93805488297012 15.0 1.0
# [3] [3] 102.33071025020175 15.0 2.4
# ...

# %%
figure = figureGenerator()
figure.init_figure()
figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
vmin = 75
vmax = 100
figure.plot_map(
    xdata=data['# boron_feed']*1000, 
    ydata=data["boron_limit"]*1000,
    zdata=(data['RO1_Boron_rej'] + data['RO1_Boron_rej']*data['RO2_Boron_rej'])*100,
    text=True,
    textfontsize= 9,
    sig_figs_text= 1,
    text_color="black",
    build_map=True,
    vmin=vmin,
    vmax=vmax,
    )
zticks = np.linspace(vmin,vmax,5)
figure.add_colorbar(zticks=zticks, zformat=1, zlabel="Overall boron rejection (%)", labelpad=15)
xticks = [1, 5, 10, 15, 20]
yticks = [0.3, 0.5, 1, 2.4]

figure.set_axis_ticklabels(
    xticklabels=xticks,
    yticklabels=yticks,
    xlabel="Feed concentration of boron (mg/L)",
    ylabel="Boron regulation (mg/L)",
)

plt.savefig("Rej_BWRO2_map", dpi=600, bbox_inches='tight')
# Out:
# C:\Users\sss0031\AppData\Local\Temp\2\ipykernel_16248\3451441555.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
# (20,)
# [ 1.  5. 10. 15. 20.] [0.3 0.5 1.  2.4]
# [0] [0] 78.57142999999999 1.0 0.3
# [0] [1] 76.460805 1.0 0.5
# [0] [2] 76.460805 1.0 1.0
# [0] [3] 76.460805 1.0 2.4
# [1] [0] 96.80851 5.0 0.3
# [1] [1] 94.444445 5.0 0.5
# [1] [2] 87.5 5.0 1.0
# [1] [3] 76.460805 5.0 2.4
# [2] [0] 98.45361 10.0 0.3
# [2] [1] 97.36842 10.0 0.5
# [2] [2] 94.444445 10.0 1.0
# [2] [3] 84.21053 10.0 2.4
# [3] [0] 98.97959 15.0 0.3
# [3] [1] 98.27586 15.0 0.5
# [3] [2] 96.42857000000001 15.0 1.0
# [3] [3] 90.47619 15.0 2.4
# [4] [0] 99.23858 20.0 0.3
# [4] [1] 98.71795 20.0 0.5
# [4] [2] 97.36842 20.0 1.0
# [4] [3] 93.18181999999999 20.0 2.4
# ...

# %%
figure = figureGenerator()
figure.init_figure()
figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
vmin = 0
vmax = 1
figure.plot_map(
    xdata=data['# boron_feed']*1000, 
    ydata=data["boron_limit"]*1000,
    zdata=data['SEC_Boron'],
    text=True,
    textfontsize= 9,
    sig_figs_text= 1,
    text_color="black",
    build_map=True,
    vmin=vmin,
    vmax=vmax,
    )
zticks = np.linspace(vmin,vmax,5)
figure.add_colorbar(zticks=zticks, zformat=1, zlabel="SEC (kWh/g boron removed)")
xticks = [1, 5, 10, 15, 20]
yticks = [0.3, 0.5, 1, 2.4]

figure.set_axis_ticklabels(
    xticklabels=xticks,
    yticklabels=yticks,
    xlabel="Feed concentration of boron (mg/L)",
    ylabel="Boron regulation (mg/L)",
)

plt.savefig("RO2_SEC_BWRO2_map", dpi=600, bbox_inches='tight')
# Out:
# C:\Users\sss0031\AppData\Local\Temp\2\ipykernel_16248\305400527.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
# (20,)
# [ 1.  5. 10. 15. 20.] [0.3 0.5 1.  2.4]
# [0] [0] 3.841081 1.0 0.3
# [0] [1] 3.95458 1.0 0.5
# [0] [2] 3.95458 1.0 1.0
# [0] [3] 3.95458 1.0 2.4
# [1] [0] 0.5720744 5.0 0.3
# [1] [1] 0.5975006 5.0 0.5
# [1] [2] 0.6721888 5.0 1.0
# [1] [3] 0.790916 5.0 2.4
# [2] [0] 0.27719 10.0 0.3
# [2] [1] 0.2830261 10.0 0.5
# [2] [2] 0.2987503 10.0 1.0
# [2] [3] 0.3537836 10.0 2.4
# [3] [0] 0.1829073 15.0 0.3
# [3] [1] 0.1854306 15.0 0.5
# [3] [2] 0.1920536 15.0 1.0
# [3] [3] 0.2133932 15.0 2.4
# [4] [0] 0.136484 20.0 0.3
# [4] [1] 0.1378841 20.0 0.5
# [4] [2] 0.1415131 20.0 1.0
# [4] [3] 0.1527701 20.0 2.4
# ...

# %%
# data1 = data[(data["boron_limit"] == 3.000000e-04) ]
# data2 = data[(data["boron_limit"] == 5.00000e-04) ]
# data3 = data[(data["boron_limit"] == 1.0000e-03) ]
# data4 = data[(data["boron_limit"] == 2.4000e-03) ]

# fig = figureGenerator()
# fig.init_figure(width=3.25*1.4,
#                 height=3.25*1.1,)
# fig.plot_line(
#         xdata=data4['# boron_feed']*1000, 
#         ydata=data4['LCOW'] - 6.615159e-01,
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=dark,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )
# fig.plot_line(
#         xdata=data3['# boron_feed']*1000, 
#         ydata=data3['LCOW'] - 6.615159e-01,
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=mid_dark,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )
# fig.plot_line(
#         xdata=data2['# boron_feed']*1000, 
#         ydata=data2['LCOW'] - 6.615159e-01,
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=mid_light,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )
# fig.plot_line(
#         xdata=data1['# boron_feed']*1000, 
#         ydata=data1['LCOW'] - 6.615159e-01,
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=light,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )

# xformat=[[0, 20], 5]
# yformat=[[0.225, 0.375], 0.025]
# # # x-pltis
# spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

# plt.xlabel("Feed concentration of boron (mg/L)")
# plt.ylabel("LCOW difference ($\$$/m$^3$)")

# plt.savefig("LCOW_diff_BWRO2", dpi=600, bbox_inches='tight')

# %%
# data1 = data[(data["boron_limit"] == 3.000000e-04) ]
# data2 = data[(data["boron_limit"] == 5.00000e-04) ]
# data3 = data[(data["boron_limit"] == 1.0000e-03) ]
# data4 = data[(data["boron_limit"] == 2.4000e-03) ]

# fig = figureGenerator()
# fig.init_figure(width=3.25*1.4,
#                 height=3.25*1.1,)
# fig.plot_line(
#         xdata=data4['# boron_feed']*1000, 
#         ydata=100*((data4['LCOW'] - 6.615159e-01)/6.615159e-01),
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=dark,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )
# fig.plot_line(
#         xdata=data3['# boron_feed']*1000, 
#         ydata=100*((data3['LCOW'] - 6.615159e-01)/6.615159e-01),
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=mid_dark,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )
# fig.plot_line(
#         xdata=data2['# boron_feed']*1000, 
#         ydata=100*((data2['LCOW'] - 6.615159e-01)/6.615159e-01),
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=mid_light,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )
# fig.plot_line(
#         xdata=data1['# boron_feed']*1000, 
#         ydata=100*((data1['LCOW'] - 6.615159e-01)/6.615159e-01),
#         marker="o",
#         markersize=4,
#         markerfacecolor="white",
#         ls="-",
#         lw=1.5,
#         color=light,
#         ax_idx=0,
#         zorder=4,
#         clip_on=True,
#         save_label=None,
#         sort_data=True,
#         log_data=True,
#     )

# xformat=[[0, 20], 5]
# yformat=[[35,55], 5]
# # # x-pltis
# spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)
# plt.xlabel("Feed concentration of boron (mg/L)")
# plt.ylabel("Change in LCOW (%)")

# plt.savefig("LCOW_%diff_BWRO2", dpi=600, bbox_inches='tight')

# %%
data = pd.read_csv(r'G:\My Drive\Research\Dev\Boron Surrogate\sensitivity_full_flowsheet_membrane_properties_1.csv')
data = data[data["# boron_feed"] <= 20/1000]

# %%
data1 = data[(data["boron_limit"] == 3.000000e-04) ]
data2 = data[(data["boron_limit"] == 5.00000e-04) ]
data3 = data[(data["boron_limit"] == 1.0000e-03) ]
data4 = data[(data["boron_limit"] == 2.4000e-03) ]

fig = figureGenerator()
fig.init_figure(width=3.25*1.4,
                height=3.25*1.1,)
fig.plot_line(
        xdata=data4['# boron_feed']*1000, 
        ydata=data4['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data3['# boron_feed']*1000, 
        ydata=data3['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_dark,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data2['# boron_feed']*1000, 
        ydata=data2['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=mid_light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
fig.plot_line(
        xdata=data1['# boron_feed']*1000, 
        ydata=data1['RO1_Boron_rej']*100,
        marker="o",
        markersize=4,
        markerfacecolor="white",
        ls="-",
        lw=1.5,
        color=light,
        ax_idx=0,
        zorder=4,
        clip_on=True,
        save_label=None,
        sort_data=True,
        log_data=True,
    )
plt.xscale('log')
plt.legend(["2.40 mg/L","1.00 mg/L","0.50 mg/L","0.30 mg/L"], title="Boron regulation", frameon=False)

xformat=[[0, 20], 5]
yformat=[[50, 100], 10]
# # x-pltis
spacing_factor = 3
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# y-pltis
ylim = yformat[0]
yinc = yformat[1]
plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

plt.xlabel("Feed concentration of boron (mg/L)")
plt.ylabel("Required boron rejection (%)")

plt.savefig("Rej_req_1stage", dpi=600, bbox_inches='tight')

# %%
s1 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_1.csv")
s2 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_2.csv")
s3 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_3.csv")
s4 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_4.csv")
s5 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_5.csv")
s6 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_6.csv")
s7 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_7.csv")
s8 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_8.csv")
s9 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_9.csv")
s10 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_10.csv")
s11 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_11.csv")
s12 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_12.csv")
s13 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_13.csv")
s14 = pd.read_csv(r"C:\Users\sss0031\Documents\GitHub\watertap\sensitivity_lcow_14.csv")

# %%
# Original parameter names and grouping labels
parameters = ["HCl cost", "NaOH cost", "Electricity cost", "Water permeability", 
              "Water permeability", "Salt permeability", "Salt permeability",
              "Boron rejection in 1st pass RO", "Membrane cost", "Membrane replacement rate", 
              "Pump capital cost", "Mixer capital cost", "Boron rejection in 2nd pass RO","Feed pH of 1st pass RO"]

# Sample data for LCOW_low and LCOW_high (the reordered values should match your data)
LCOW_low = [s1["LCOW"][0], s2["LCOW"][0], s3["LCOW"][0], s4["LCOW"][0], s5["LCOW"][0], 
            s6["LCOW"][0], s7["LCOW"][0], s8["LCOW"][0], s9["LCOW"][0], s10["LCOW"][0], 
            s11["LCOW"][0], s12["LCOW"][0], s13["LCOW"][0], s14["LCOW"][0]]

LCOW_high = [s1["LCOW"][1], s2["LCOW"][1], s3["LCOW"][1], s4["LCOW"][1], s5["LCOW"][1], 
             s6["LCOW"][1], s7["LCOW"][1], s8["LCOW"][1], s9["LCOW"][1], s10["LCOW"][1], 
             s11["LCOW"][1], s12["LCOW"][1], s13["LCOW"][1], s14["LCOW"][1]]

# New ordered indices based on the new parameter order
indices_order = [13, 7, 12, 8, 9, 10, 11, 0, 1, 2]

# Reorder LCOW_low and LCOW_high based on the new indices
parameters = [parameters[i] for i in indices_order]
LCOW_low = [LCOW_low[i] for i in indices_order]
LCOW_high = [LCOW_high[i] for i in indices_order]


fig = figureGenerator()
fig.init_figure()

light = color_list[0]
mid_light = color_list[1]
dark = color_list[8]
econ =  color_list[2]
econ2 =  color_list[3]
color = [dark,
        mid_light,
        light,
    econ,econ,econ,econ,
    econ2,econ2,econ2,econ2,]

y_pos = np.arange(len(parameters))

width = []
bottom = []
for low, high in zip(LCOW_low, LCOW_high):
    width.append(abs(high - low))
    bottom.append(min(low, high))

# Loop over each parameter to plot individual bars with unique labels
for i, (y, w, b, label,c) in enumerate(zip(y_pos, width, bottom, parameters,color)):
    fig.plot_bar(
        [y],  # single y position
        [w],  # single width
        bottom=[b],  # single bottom position
        width=0.3,
        vertical=False,
        color=c,
        save_label=label,  # individual label for each bar
    )

# Additional plot settings
plt.yticks(y_pos, parameters)
plt.xlim(-11.5, 11.5)
plt.xlabel('Change in LCOW (%)')
plt.gca().invert_yaxis()

plt.savefig("boron_sensitivity", dpi=600, bbox_inches='tight')

# %%
data = pd.read_csv(r'C:\Users\sss0031\Documents\GitHub\watertap\outputs_results.csv')

# %%
f_crf = 0.1
f_util = 0.9

# %%
figure = figureGenerator()
figure.init_figure()
figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
vmin = data['NaOH cost'].min()
vmax = data['NaOH cost'].max()
figure.plot_map(
    xdata=data['# boron_feed']*1000, 
    ydata=data["boron_limit"]*1000,
    zdata=data['NaOH cost'],
    text=True,
    textfontsize= 9,
    sig_figs_text= 1,
    text_color="black",
    build_map=True,
    vmin=vmin,
    vmax=vmax,
    )
zticks = np.linspace(vmin,vmax,5)
figure.add_colorbar(zticks=zticks, zformat=1, zlabel="NaOH cost (\$/yr)", labelpad=15)
xticks = [1, 5, 10, 15, 20]
yticks = [0.3, 0.5, 1, 2.4]

figure.set_axis_ticklabels(
    xticklabels=xticks,
    yticklabels=yticks,
    xlabel="Feed concentration of boron (mg/L)",
    ylabel="Boron regulation (mg/L)",
)

plt.savefig("RO2_SEC_BWRO2_map", dpi=600, bbox_inches='tight')
# Out:
# C:\Users\sss0031\AppData\Local\Temp\2\ipykernel_16248\223827123.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   figure.colorMaps["color_map"] = cm.get_cmap("GnBu")
# (24,)
# [ 1.  5. 10. 15. 20. 25.] [0.3 0.5 1.  2.4]
# [0] [0] 32.38219 1.0 0.3
# [0] [1] 18.77493 1.0 0.5
# [0] [2] 18.77493 1.0 1.0
# [0] [3] 18.77493 1.0 2.4
# [1] [0] 567.1834 5.0 0.3
# [1] [1] 328.5553 5.0 0.5
# [1] [2] 147.7145 5.0 1.0
# [1] [3] 18.77493 5.0 2.4
# [2] [0] 1086.317 10.0 0.3
# [2] [1] 682.5639 10.0 0.5
# [2] [2] 328.5553 10.0 1.0
# [2] [3] 95.52646 10.0 2.4
# [3] [0] 1478.289 15.0 0.3
# [3] [1] 993.9347 15.0 0.5
# [3] [2] 507.8779 15.0 1.0
# [3] [3] 199.9759 15.0 2.4
# [4] [0] 1786.853 20.0 0.3
# [4] [1] 1255.802 20.0 0.5
# [4] [2] 682.5639 20.0 1.0
# [4] [3] 271.0331 20.0 2.4
# [5] [0] nan 25.0 0.3
# ...

# %%
data1 = data[(data["boron_limit"] == 0.5/1000) ]
Q = data1["Product water"]

elec_usage = data1["P1 Capital Cost"] /(data1["P1 Capital Cost"]+data1["P2 Capital Cost"])
labels = ["1st pass CAPEX","1st pass OPEX","2nd pass CAPEX","2nd pass OPEX","Chemical addition CAPEX","Chemical addition OPEX"]

x = data1["# boron_feed"]*1000

y1 = (f_crf*data1["P1 Capital Cost"] + f_crf*data1["RO1 Capital Cost"])/(f_util*Q)
y2 = (data1["Electric cost"]*elec_usage + data1["RO1 Fixed Operating Cost"] + data1["Chem and Main"]*(1/3))/(f_util*Q)

y3 = (f_crf*data1["P2 Capital Cost"] + f_crf*data1["RO2 Capital Cost"])/(f_util*Q)
y4 = (data1["Electric cost"]*(1-elec_usage) + data1["RO2 Fixed Operating Cost"]+ data1["Chem and Main"]*(1/3))/(f_util*Q)

y5 = (f_crf*data1["M2 Capital Cost"] + f_crf*data1["M1 Capital Cost"])/(f_util*Q)
y6 = (data1["NaOH cost"] + data1["HCl cost"]+ data1["Chem and Main"]*(1/3))/(f_util*Q)

y = np.vstack([y1,y2,y3,y4,y5,y6])
colors=[color_list[0],color_list[0],color_list[1],color_list[1],color_list[8],color_list[8]]
hatches = ['//', None, '//',None, '//',None]
bottom = np.zeros_like(x)

fig = figureGenerator()
fig.init_figure(width=3.25*1.4,
                height=3.25*1.1,)

for i, layer in enumerate(y):
    plt.fill_between(x, bottom, bottom + layer, label=labels[i], 
                        color=colors[i], hatch=hatches[i], edgecolor="black")
    bottom += layer
plt.plot(x,data1["LCOW"],color='black', linestyle='-', marker='^')
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.15), ncol=3, frameon=False)

plt.ylabel("LCOW ($/m3)")
plt.xlabel("Boron feed (mg/L)")
plt.ylim([0,1.2])


plt.savefig("LCOW_breakdown_overall_boronfeed", dpi=600, bbox_inches='tight')
plt.show()

# %%
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

# %%
data1 = data[(data["# boron_feed"] == 5/1000)]
Q = data1["Product water"]
elec_usage = data1["P1 Capital Cost"] / (data1["P1 Capital Cost"] + data1["P2 Capital Cost"])

x = data1["boron_limit"] * 1000

y1 = (f_crf*data1["P1 Capital Cost"] + f_crf*data1["RO1 Capital Cost"]) / (f_util*Q)
y2 = (data1["Electric cost"]*elec_usage + data1["RO1 Fixed Operating Cost"] + data1["Chem and Main"]*(1/3)) / (f_util*Q)
y3 = (f_crf*data1["P2 Capital Cost"] + f_crf*data1["RO2 Capital Cost"]) / (f_util*Q)
y4 = (data1["Electric cost"]*(1-elec_usage) + data1["RO2 Fixed Operating Cost"] + data1["Chem and Main"]*(1/3)) / (f_util*Q)
y5 = (f_crf*data1["M2 Capital Cost"] + f_crf*data1["M1 Capital Cost"]) / (f_util*Q)
y6 = (data1["NaOH cost"] + data1["HCl cost"] + data1["Chem and Main"]*(1/3)) / (f_util*Q)

y      = np.vstack([y1, y2, y3, y4, y5, y6])
colors  = [color_list[0], color_list[0], color_list[1], color_list[1], color_list[8], color_list[8]]
hatches = ['//',           None,           '//',           None,           '//',           None]

bottom = np.zeros_like(x)

fig = figureGenerator()
fig.init_figure(width=3.25*1.4, height=3.25*1.1)

for i, layer in enumerate(y):
    plt.fill_between(x, bottom, bottom + layer,
                     facecolor=colors[i],
                     hatch=hatches[i],
                     edgecolor='black',
                     linewidth=0.5)
    bottom += layer

# --- Color handles: one per unit ---
color_handles = [
    mpatches.Patch(facecolor=color_list[0], edgecolor='black', linewidth=0.5, label='1st pass RO'),
    mpatches.Patch(facecolor=color_list[1], edgecolor='black', linewidth=0.5, label='2nd pass RO'),
    mpatches.Patch(facecolor=color_list[8], edgecolor='black', linewidth=0.5, label='Chemical addition'),
]

# --- Hatch handles: one per cost type ---
hatch_handles = [
    mpatches.Patch(facecolor='white', edgecolor='black', hatch='//', linewidth=0.5, label='CAPEX'),
    mpatches.Patch(facecolor='white', edgecolor='black', hatch='',   linewidth=0.5, label='OPEX'),
]

# Combine into a single row — add a blank separator entry between the two groups
separator = mpatches.Patch(visible=False, label='')  # invisible spacer

all_handles = hatch_handles + color_handles 

plt.legend(
    handles=all_handles,
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=len(all_handles),
    frameon=False,
    fontsize=9,
    handlelength=1.5,      # length of the colored patch (default 2.0)
    handletextpad=0.3,     # gap between patch and its label (default 0.8)
    columnspacing=0.6,     # gap between columns (default 2.0)
)

plt.ylabel("LCOW ($/m³)")
plt.xlabel("Boron limit (mg/L)")
plt.ylim([0, 1.05])
plt.savefig("LCOW_breakdown_overall_boronreg", dpi=600, bbox_inches='tight')
plt.show()

# %%
# data1 = data[(data["# boron_feed"] == 5/1000) ]
# Q = data1["Product water"]

# elec_usage = data1["P1 Capital Cost"] /(data1["P1 Capital Cost"]+data1["P2 Capital Cost"])
# labels = ["2nd pass CAPEX","2nd pass OPEX","Chemical addition CAPEX","Chemical addition OPEX"]

# x = data1["boron_limit"]*1000

# # y1 = (f_crf*data1["P1 Capital Cost"] + f_crf*data1["RO1 Capital Cost"])/(f_util*Q)
# # y2 = (data1["Electric cost"]*elec_usage + data1["RO1 Fixed Operating Cost"] + data1["Chem and Main"]*(1/3))/(f_util*Q)

# y3 = (f_crf*data1["P2 Capital Cost"] + f_crf*data1["RO2 Capital Cost"])/(f_util*Q)
# y4 = (data1["Electric cost"]*(1-elec_usage) + data1["RO2 Fixed Operating Cost"]+ data1["Chem and Main"]*(1/3))/(f_util*Q)

# y5 = (f_crf*data1["M2 Capital Cost"] )/(f_util*Q) #+ f_crf*data1["M1 Capital Cost"]
# y6 = (data1["NaOH cost"] + data1["Chem and Main"]*(1/3))/(f_util*Q) #+ data1["HCl cost"]

# y = np.vstack([y3,y4,y5,y6])
# colors=[color_list[1],color_list[1],color_list[8],color_list[8]]
# hatches = ['//',None, '//',None]
# bottom = np.zeros_like(x)

# fig = figureGenerator()
# fig.init_figure(width=3.25*1.4,
#                 height=3.25*1.1,)

# for i, layer in enumerate(y):
#     plt.fill_between(x, bottom, bottom + layer, label=labels[i], 
#                         color=colors[i], hatch=hatches[i], edgecolor="black")
#     bottom += layer

# plt.legend(loc="upper center", 
#           bbox_to_anchor=(0.5, -0.15), 
#           ncol=2, 
#           frameon=False)

# xformat=[[0.3, 2.4], .3]
# yformat=[[0.0, 0.35], 0.05]
# # # x-pltis
# spacing_factor = 5
# xlim = xformat[0]
# xinc = xformat[1]
# plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
# plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# # y-pltis
# ylim = yformat[0]
# yinc = yformat[1]
# plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
# plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

# plt.ylabel("LCOW ($/m3)")
# plt.xlabel("Boron regulation (mg/L)")
# # plt.ylim([0,0.35])
# # plt.ylim([0.3,2.4])
# plt.show()
# plt.savefig("LCOW_breakdown_2pass_boronreg", dpi=600, bbox_inches='tight')

# %%
data1 = data[(data["boron_limit"] == 5.00000e-04) ]
Q = data1["Product water"]

elec_usage = data1["P1 Capital Cost"] /(data1["P1 Capital Cost"]+data1["P2 Capital Cost"])
labels = ["2nd pass CAPEX","2nd pass OPEX","pH swing CAPEX","pH swing OPEX"]

x = data1["# boron_feed"]*1000

y1 = (f_crf*data1["P1 Capital Cost"] + f_crf*data1["RO1 Capital Cost"])/(f_util*Q)
y2 = (data1["Electric cost"]*elec_usage + data1["RO1 Fixed Operating Cost"] + data1["Chem and Main"]*(1/3))/(f_util*Q)

y3 = (f_crf*data1["P2 Capital Cost"] + f_crf*data1["RO2 Capital Cost"])/(f_util*Q)
y4 = (data1["Electric cost"]*(1-elec_usage) + data1["RO2 Fixed Operating Cost"]+ data1["Chem and Main"]*(1/3))/(f_util*Q)

y5 = (f_crf*data1["M2 Capital Cost"] + f_crf*data1["M1 Capital Cost"])/(f_util*Q)
y6 = (data1["NaOH cost"] + data1["HCl cost"]+ data1["Chem and Main"]*(1/3))/(f_util*Q)

y = np.vstack([y3,y4,y5,y6])
colors=[color_list[1],color_list[1],color_list[8],color_list[8]]
hatches = ['//',None, '//',None]
bottom = np.zeros_like(x)

# fig, ax = plt.subplots()
fig = figureGenerator()
fig.init_figure(width=3.25*1.4,
                height=3.25*1.1,)

for i, layer in enumerate(y):
    plt.fill_between(x, bottom, bottom + layer, label=labels[i], 
                        color=colors[i], hatch=hatches[i], edgecolor="black")
    bottom += layer
plt.legend(loc="upper center", 
          bbox_to_anchor=(0.5, -0.15), 
          ncol=2, 
          frameon=False)

xformat=[[0,25], 5]
yformat=[[0.0, 0.45], 0.05]
# # x-pltis
spacing_factor = 5
xlim = xformat[0]
xinc = xformat[1]
plt.xlim(xlim[0]-xinc/spacing_factor, xlim[1]+xinc/spacing_factor)
plt.xticks(np.linspace(xlim[0], xlim[1], int(round((xlim[1]-xlim[0])/xinc))+1))
# y-pltis
ylim = yformat[0]
yinc = yformat[1]
plt.ylim(ylim[0]-yinc/spacing_factor, ylim[1]+yinc/spacing_factor)
plt.yticks(np.linspace(ylim[0], ylim[1], int(round((ylim[1]-ylim[0])/yinc))+1))

plt.ylabel("LCOW ($/m3)")
plt.xlabel("Boron concentration in the feed (mg/L)")
# plt.ylim([0,0.35])
# plt.ylim([0.3,2.4])

plt.savefig("LCOW_breakdown_2pass_boronfeed", dpi=600, bbox_inches='tight')
plt.show()
